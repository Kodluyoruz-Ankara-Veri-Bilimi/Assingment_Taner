# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from impme import *

# %%
df = pd.read_excel('HW_Data_Set.xlsx', index_col=None)

# %%
dfInfo = Basic_Information(df)

# %%
dfInfo.Info()
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...  ind_416  ind_418  ind_420  ind_422  ind_424   ind_426  \
# 0   17.62   11.73  ...    -49.6      -54     -152     -353      1.0  0.498547
# 1   18.16   12.22  ...    -55.6      -60     -158     -359      1.0  0.537088
# 2   17.86   12.28  ...    -58.4      -60     -160     -362      1.0  0.615169
# 3   14.76   12.61  ...    -61.8      -65     -166     -367      1.0  0.661517
# 4   11.92   14.25  ...    -79.8      -86     -186     -388      1.0  0.747204
#
#     ind_428  20_target  50_target  90_target
# ...

# %%
dfvis = Vis(df)

# %%
dfvis.corrheat("90_target",.3)
# Out:
# 90_target    1.000000
# 50_target    0.940916
# 20_target    0.355950
# ind_18       0.140877
# ind_17       0.129277
#                ...
# ind_128     -0.061283
# ind_26      -0.086192
# ind_330     -0.093811
# ind_418     -0.096903
# ind_324     -0.103707
# Name: 90_target, Length: 133, dtype: float64

# %%
dfvis.scatter("90_target")
# Out:
# C:\Users\Taner\Desktop\kodluyoruz Bootcamp\kodluyoruz ödev\impme.py:145: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-69c006de10b4> in <module>
# ----> 1 dfvis.scatter("20_target")
#
# ~\Desktop\kodluyoruz Bootcamp\kodluyoruz ödev\impme.py in scatter(self, target)
#     145             fig, ax = plt.subplots()
#     146
# --> 147             ax.scatter(self.data[x], self.data[target])
#     148
#     149             ax.set_title(target)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
dfvis.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2d35a4841c8e> in <module>
# ----> 1 dfvis.hist()
#
# ~\Desktop\kodluyoruz Bootcamp\kodluyoruz ödev\impme.py in hist(self)
#     118
#     119         for i in self.data.columns:
# --> 120             fig=self.data[i].plot.hist()
#     121             fig.set_title(i)
#     122             plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, by, bins, **kwargs)
#    1178             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1179         """
# -> 1180         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1181
#    1182     def kde(self, bw_method=None, ind=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# ...

# %%
df.select_dtypes(include= "object")
# Out:
#      ind_109 ind_420 ind_422
# 0      GREEN    -152    -353
# 1      GREEN    -158    -359
# 2      GREEN    -160    -362
# 3      GREEN    -166    -367
# 4      GREEN    -186    -388
# ...      ...     ...     ...
# 6162     RED     -11    -270
# 6163     RED     -12    -271
# 6164   GREEN     -21    -280
# 6165   GREEN     -33    -292
# 6166   GREEN     -28    -288
#
# [6167 rows x 3 columns]

# %%
a = df[["ind_420", "ind_422"]]

# %%
dff = df.drop(labels=a,axis = 1)

# %%
dff
# Out:
#       ind_5  ind_6       ind_8      ind_9     ind_10     ind_12     ind_13  \
# 0        19     17  100.000000  85.714286  14.285714  72.363515  60.808814
# 1        24     19  100.000000  78.571429  21.428571  74.275883  64.366798
# 2        30     24  100.000000  71.428571  28.571429  75.140402  65.915803
# 3        37     30  100.000000  64.285714  35.714286  76.677846  68.584234
# 4        41     37  100.000000  57.142857  42.857143  81.603007  76.455495
# ...     ...    ...         ...        ...        ...        ...        ...
# 6162     27     31   57.142857  28.571429  28.571429  60.010531  32.362582
# 6163     22     27   50.000000  21.428571  28.571429  60.209998  32.914628
# 6164     19     22   42.857143  14.285714  28.571429  64.329611  43.550592
# 6165     19     19  100.000000   7.142857  92.857143  69.027764  54.130755
# 6166     19     19   92.857143   0.000000  92.857143  65.157180  45.524973
#
# ...

# %%
df["ind_109"].value_counts()
# Out:
# GREEN    3132
# RED      3035
# Name: ind_109, dtype: int64

# %%
sns.boxplot(x = "ind_109", y = "90_target", data= df)

# %%
# KBinsDiscretizer ve binarizer yapılmış.

# %%
dff["ind_109"]=pd.get_dummies(dff["ind_109"])

# %%
dff.head()
# Out:
#    ind_5  ind_6  ind_8      ind_9     ind_10     ind_12     ind_13  ind_14  \
# 0     19     17  100.0  85.714286  14.285714  72.363515  60.808814   23.80
# 1     24     19  100.0  78.571429  21.428571  74.275883  64.366798   11.45
# 2     30     24  100.0  71.428571  28.571429  75.140402  65.915803    8.75
# 3     37     30  100.0  64.285714  35.714286  76.677846  68.584234    7.80
# 4     41     37  100.0  57.142857  42.857143  81.603007  76.455495   14.90
#
#    ind_15  ind_16  ...   ind_412  ind_414  ind_416  ind_418  ind_424  \
# 0   17.62   11.73  ...  0.002371      2.0    -49.6      -54      1.0
# 1   18.16   12.22  ...  0.003074      0.8    -55.6      -60      1.0
# 2   17.86   12.28  ...  0.003561      2.7    -58.4      -60      1.0
# 3   14.76   12.61  ...  0.004366      0.9    -61.8      -65      1.0
# 4   11.92   14.25  ...  0.004198      0.1    -79.8      -86      1.0
#
#     ind_426   ind_428  20_target  50_target  90_target
# ...

# %%
X = dff.drop(columns= ["90_target","50_target","20_target"])

y = dff["90_target"]

# %%
# Tüm X leri 0-1 arasında scale ettik. PCA den önce.

# %%
#from sklearn.decomposition import PCA
#from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 42)

# %%
X_train.head()
# Out:
#       ind_5  ind_6      ind_8       ind_9      ind_10     ind_12      ind_13  \
# 6066    -52    -49   0.000000  100.000000 -100.000000  22.470927 -246.019471
# 3710    -21    -16  42.857143   85.714286  -42.857143  38.738683  -59.139903
# 5095     64     65  85.714286    0.000000   85.714286  65.654564   46.687664
# 5427    -36    -32  21.428571  100.000000  -78.571429  21.281119 -270.900108
# 344      -5     -6  14.285714   50.000000  -35.714286  44.949261  -23.473070
#
#       ind_14  ind_15  ind_16  ...  ind_406  ind_407  ind_410   ind_412  \
# 6066    9.05   12.30   12.50  ...       70       14       25 -0.003944
# 3710   11.95   16.44   14.30  ...       29       -1       19 -0.004829
# 5095   12.45   14.34   18.03  ...      -61       10        1  0.007490
# 5427   18.45   14.60   15.34  ...       57       12       27 -0.002340
# 344     8.15    9.64   10.71  ...        8        3       -1 -0.001756
#
#       ind_414  ind_416  ind_418  ind_424   ind_426   ind_428
# ...

# %%
y_test.shape
# Out:
# (1234,)

# %%
model = Model(dff)

# %%
model.linear_pca(X_train, X_test, y_train, y_test)
# Out:
# [37.72 50.2  55.75 60.29 63.67 66.8  69.47 71.5  73.23 74.83 76.32 77.7
#  79.03 80.26 81.41 82.48 83.48 84.38 85.2  86.   86.73 87.45 88.13 88.8
#  89.41 89.98 90.52 91.05 91.51 91.96 92.38 92.78 93.16 93.53 93.88 94.19
#  94.5  94.79 95.07 95.35 95.6  95.83 96.05 96.27 96.47 96.66 96.85 97.03
#  97.2  97.36 97.51 97.65 97.78 97.91 98.02 98.13 98.24 98.34 98.43 98.52]
# mean_squared_error  : 38.059276937823384
# r2_score :  -0.07082483718644617
